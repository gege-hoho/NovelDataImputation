# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Version 3 of FoodClassification Experiments
# This Version contains a generalized Dataset from the Version 2. In order to allow for CNN usage. It contains the definition of two CNN models
#
# 1.   FoodItem2.1: Has 4 filters (1,3,4,5)
# 2.   FoodItem2.0: Has 3 filters (3,4,5)
# 3.   FoodItem1.0: Feed Forward which only works on the mean embedding

# %%
# !mkdir data
# !mkdir data/models
# !cp drive/MyDrive/Uni/Masterarbeit/data/embeddingmodel.zip data/models/zip.zip
# !unzip -o data/models/zip.zip -d  data/models 
# !cp drive/MyDrive/Uni/Masterarbeit/data/dataset data/dataset.csv
# !cp drive/MyDrive/Uni/Masterarbeit/data/dataset_train data/dataset_train
# !cp drive/MyDrive/Uni/Masterarbeit/data/dataset_test data/dataset_test
# !cp drive/MyDrive/Uni/Masterarbeit/data/crawled.csv data/crawled.csv
# Out:
# Archive:  data/models/zip.zip
#   inflating: data/models/bigram_model.pkl
#   inflating: data/models/mymodel
#   inflating: data/models/mymodel.wv.vectors.npy
#   inflating: data/models/mymodel.trainables.syn1neg.npy

# %%
# %%capture
# !pip install wandb --upgrade

# %%
import pandas as pd
import math
import numpy as np
import torch
import torchvision
from torch.nn import Module
from torch.utils.data import Dataset, DataLoader
from gensim.models import KeyedVectors
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import random
from gensim.models.phrases import Phrases, Phraser
import nltk
from nltk.tokenize import RegexpTokenizer
import re
import time
import urllib.request
import os.path
import wandb

# %%
mapping = {'Baking':['Baking Additives & Extracts','Baking Decorations & Dessert Toppings','Baking/Cooking Mixes/Supplies'],
'Biscuits/Cookies':['Biscuits/Cookies','Biscuits/Cookies (Shelf Stable)'],
'Bread':['Bread','Bread & Muffin Mixes','Breads & Buns'],
'Cakes':['Cake, Cookie & Cupcake Mixes','Cakes - Sweet (Frozen)','Cakes, Cupcakes, Snack Cakes','Croissants, Sweet Rolls, Muffins & Other Pastries','Pies/Pastries - Sweet (Shelf Stable)'],
'Soup':['Canned Soup','Canned Condensed Soup','Other Soups','Chili & Stew'],
'Cereal':['Cereal','Cereals Products - Ready to Eat (Shelf Stable)','Processed Cereal Products'],
'Chips, Pretzels & Snacks': ['Chips, Pretzels & Snacks','Chips/Crisps/Snack Mixes - Natural/Extruded (Shelf Stable)','Popcorn, Peanuts, Seeds & Related Snacks','Wholesome Snacks','Crackers & Biscotti','Flavored Snack Crackers','Other Snacks','Snacks'],
'Fish & Seafood': ['Fish  Unprepared/Unprocessed','Fish & Seafood','Fish – Unprepared/Unprocessed','Canned Seafood','Canned Tuna','Frozen Fish & Seafood','Shellfish Unprepared/Unprocessed'],
'Chocolate':['Confectionery Products','Chocolate'],
'Oils & Butters':['Oils Edible','Nut & Seed Butters','Butter & Spread','Vegetable & Cooking Oils'],
'Dough Based Products':['Dough Based Products / Meals','Frozen Bread & Dough'],
'Bacon, Sausages & Ribs':['Frozen Bacon, Sausages & Ribs','Frozen Sausages, Hotdogs & Brats','Bacon, Sausages & Ribs','Sausages, Hotdogs & Brats'],
'Flours & Grains':['Flours & Corn Meal','Grains/Flour'],
'Herbs & Spices':['Herbs & Spices','Herbs/Spices/Extracts'],
'Meat/Poultry/Other Animals':['Meat/Poultry/Other Animals  Prepared/Processed','Meat/Poultry/Other Animals  Unprepared/Unprocessed',
                              'Meat/Poultry/Other Animals Sausages  Prepared/Processed','Meat/Poultry/Other Animals Sausages – Prepared/Processed',
                              'Meat/Poultry/Other Animals – Prepared/Processed','Meat/Poultry/Other Animals – Unprepared/Unprocessed',
                              'Other Frozen Meats','Poultry, Chicken & Turkey','Canned Meat','Frozen Poultry, Chicken & Turkey','Other Meats','Frozen Patties and Burgers'],
'Non Alcoholic Beverages':['Non Alcoholic Beverages  Not Ready to Drink','Non Alcoholic Beverages  Ready to Drink','Non Alcoholic Beverages – Ready to Drink'],
'Cooking Sauces':['Cooking Sauces','Oriental, Mexican & Ethnic Sauces','Other Cooking Sauces'],
'Pasta/Noodles':['Pasta by Shape & Type','Pasta/Noodles','All Noodles'],
'Subs, Sandwiches, Wraps & Burittos':['Prepared Wraps and Burittos','Prepared Subs & Sandwiches'],
'Vegetables':['Vegetables  Prepared/Processed','Vegetables – Prepared/Processed','Canned Vegetables','Tomatoes','Frozen Vegetables'],
'Vegetable Based Products / Meals':['Vegetable Based Products / Meals','Vegetable Based Products / Meals - Not Ready to Eat (Frozen)'],
'Pancakes, Waffles, French Toast & Crepes':['Frozen Pancakes, Waffles, French Toast & Crepes', 'Pancakes, Waffles, French Toast & Crepes'],
'Entrees, Sides & Small Meals': ['Entrees, Sides & Small Meals',"Frozen Appetizers & Hors D'oeuvres",'Frozen Prepared Sides'],
'Fruit  Prepared/Processed':['Fruit  Prepared/Processed','Fruit - Prepared/Processed (Shelf Stable)']}
remove = ["Baby/Infant  Foods/Beverages","Miscellanious"]

# %%
def get_device():
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu') 
    return device
  
def unify_cat(dataframe, col, cat_list,new_cat):
  #unify several categories into 1 with new name
  if new_cat not in dataframe[col].cat.categories:
    dataframe[col].cat.add_categories(new_cat,inplace = True)
  dataframe.loc[dataframe[col].isin(cat_list),col] = new_cat
  dataframe[col].cat.remove_unused_categories(inplace=True)

def getData(file_path):
  branded_food = pd.read_csv(file_path[0])
  food2 = pd.read_csv(file_path[1])
  food2 = branded_food.merge(food2, on='fdc_id')
  del branded_food
  food = pd.DataFrame(food2["description"])
  food["brand"] = food2["brand_name"].fillna("").astype(str)
  food["category"] = food2["branded_food_category"].astype('category')
  del food2
  vc = food["category"].value_counts()
  vc = vc[vc > 100]
  no_of_classes = len(vc)
  food = food[food["category"].isin(vc.index)]
  food["category"] = food["category"].cat.remove_unused_categories()
  food["description"] = food["description"].fillna("").astype(str)
  food = food[~food["category"].isnull()]
  #put similar stuff together
  for x in remove:
    food = food[food["category"] != x]
  for x,y in mapping.items():
    unify_cat(food,"category",y,x)
  food["category"] = food["category"].cat.remove_unused_categories()
  return food

def getSplittedData(file_path, stratify=True, max_data= -1,filter=10):
  data = getData(file_path)
  if max_data != -1:
    data = data.sample(max_data)
  if stratify:
    return train_test_split(data,test_size=0.2,stratify=data["category"])
  return train_test_split(data,test_size=0.2)

def early_stopping(early_stop_after):
  early_stop_counter=0
  best_early_stopping = 0
  def inner_early_stopping(current):
    nonlocal early_stop_counter, best_early_stopping
    if best_early_stopping > current:
      early_stop_counter +=1
    else:
      best_early_stopping = current
      early_stop_counter =0
    return early_stop_counter >= early_stop_after

  return inner_early_stopping

def get_confusion_matrix(y_pred,y_true,labels):
  y_pred = y_pred.cpu()
  y_true = y_true.cpu()
  cm = confusion_matrix(y_true, y_pred)
  return cm

def get_evaluation(y_pred,y_true,labels):
  d = [[0,0,0] for _ in range(len(labels))]
  for y_p, y_t in zip(y_pred,y_true):
    if y_p == y_t:
      d[y_t][0] += 1
    else:
      d[y_p][2] += 1 # false negative for class y_p
      d[y_t][1] += 1 # false positive for class y_t
  recall = [x[0]/(x[0]+x[2]) if x[0]+x[2] != 0 else np.nan for x in d]
  prec = [x[0]/(x[0]+x[1])if x[0]+x[1] != 0 else np.nan for x in d]
  return np.array(recall),np.array(prec)

def print_evaluation(values,labels,categories):
  for x,l in zip(values,labels):
    print(f"{l}: {x:.2f}")

def test_crawled(curr_model,categories):
  categories = np.array(categories)
  crawled_food = pd.read_csv("data/crawled.csv")
  crawled_food["tokens"] = crawled_food.apply(lambda row: bigram_model[fd.preprocess(row["meal_name"])], axis=1)
  crawled_x = [embedd(v) for _,v in crawled_food["tokens"].iteritems()]
  crawled_x = torch.stack(crawled_x).float().to(device)
  curr_model.eval()
  y = curr_model(crawled_x)
  y = torch.nn.functional.softmax(y,dim=1)
  y = y.cpu()
  val,idx = torch.topk(y, 1, dim=1)
  crawled_food["category"] = categories[np.array(idx[:,0])]
  crawled_food["pct"] = val[:,0].detach().numpy()
  return crawled_food

# %%
embedding_model = KeyedVectors.load("data/models/mymodel")
embedding_size = 300
bigram_model = Phrases.load("data/models/bigram_model.pkl")
bigram_model = Phraser(bigram_model)
nltk.download('stopwords')
nltk.download('wordnet')
lst_stopwords = nltk.corpus.stopwords.words("english")
custom = ["gal", "oz", "t", "tsp", "teaspoon", 
          "tablespoon", "tbl", "tbs", "tbsp",
          "fl", "oz", "gil", "ounce", "ml", "l",
          "dl", "lb", "pund", "mg", "g", "kg", "gram", "cup","cups","container","avg","homemade","piece","serving","spam","servings","grams"]
lst_stopwords.extend(custom)
tokenizer = RegexpTokenizer(r'\w+')
lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
class FoodItemDataset(Dataset):
    def __init__(self, data, token_count,device):
      self.token_count = token_count
      self.no_of_classes = len(data["category"].value_counts())
      self.codes = list(data["category"].cat.codes)
      self.cats = list(data["category"].cat.categories)
      self.embedding = [self.calc(i,row[1]) for i,row in enumerate(data.iterrows())]
      
      
      self.codes = np.array(self.codes, dtype=np.int_)
    def __len__(self):
      return len(self.embedding)

    def __getitem__(self, idx):
      return (self.codes[idx],self.embedding[idx])

    def preprocess(self,name):
      name = re.sub(r'[^\w\s]', '', str(name).lower().strip())
      name = tokenizer.tokenize(name)
      return [lemmatizer.lemmatize(x) for x in name if x not in lst_stopwords and len(x)>2 and not any(char.isdigit() for char in x)]

    def calc(self, index, row):
      if index%100000 == 0:
        print(index)
      embedding = np.zeros((self.token_count,embedding_size),dtype=float)
      tokens_brand = self.preprocess(row["brand"])
      tokens = self.preprocess(row["description"])
      #if not any(x in tokens for x in tokens_brand):
      tokens = tokens_brand + tokens
      tokens = bigram_model[tokens]
      return tokens

# %%
createData = False
device = get_device()
if createData:
  if os.path.exists("zip.zip"):
    assert False
  urllib.request.urlretrieve("https://fdc.nal.usda.gov/fdc-datasets/FoodData_Central_branded_food_csv_2021-10-28.zip", "zip.zip")
  # !unzip zip.zip -d data
  data_train, data_test = getSplittedData(("data/branded_food.csv","data/food.csv"))
  fd = FoodItemDataset(data_train,10,device)
  fd_test = FoodItemDataset(data_test,10,device)
  torch.save(fd,"data/dataset_train")
  torch.save(fd_test,"data/dataset_test")
else:
  fd = torch.load("data/dataset_train")
  fd_test = torch.load("data/dataset_test")

# %%
fd.cats
# Out:
# ['Alcohol',
#  'Bacon, Sausages & Ribs',
#  'Biscuits/Cookies',
#  'Bread',
#  'Breakfast Drinks',
#  'Breakfast Sandwiches, Biscuits & Meals',
#  'Candy',
#  'Canned & Bottled Beans',
#  'Canned Fruit',
#  'Cereal',
#  'Cereal/Muesli Bars',
#  'Cheese',
#  'Cheese/Cheese Substitutes',
#  'Chewing Gum & Mints',
#  'Chips, Pretzels & Snacks',
#  'Chocolate',
#  'Coffee',
#  'Coffee/Tea/Substitutes',
#  'Cooked & Prepared',
#  'Cookies & Biscuits',
#  'Cream',
#  'Crusts & Dough',
#  'Deli Salads',
#  'Desserts/Dessert Sauces/Toppings',
#  'Dips & Salsa',
#  'Eggs & Egg Substitutes',
#  'Energy, Protein & Muscle Recovery Drinks',
#  'Entrees, Sides & Small Meals',
#  'Fish & Seafood',
#  'Flavored Rice Dishes',
#  'French Fries, Potatoes & Onion Rings',
#  'Frozen Breakfast Sandwiches, Biscuits & Meals',
#  'Frozen Dinners & Entrees',
#  'Frozen Fruit & Fruit Juice Concentrates',
#  'Fruit  Prepared/Processed',
#  'Fruit & Vegetable Juice, Nectars & Fruit Drinks',
#  'Gelatin, Gels, Pectins & Desserts',
#  'Grain Based Products / Meals',
#  'Granulated, Brown & Powdered Sugar',
#  'Gravy Mix',
#  'Green Supplements',
#  'Health Care',
#  'Herbs & Spices',
#  'Honey',
#  'Ice Cream & Frozen Yogurt',
#  'Iced & Bottle Tea',
#  'Jam, Jelly & Fruit Spreads',
#  'Ketchup, Mustard, BBQ & Cheese Sauce',
#  'Liquid Water Enhancer',
#  'Lunch Snacks & Combinations',
#  'Meal Replacement Supplements',
#  'Mexican Dinner Mixes',
#  'Milk',
#  'Milk Additives',
#  'Other Condiments',
#  'Other Deli',
#  'Other Drinks',
#  'Other Frozen Desserts',
#  'Other Grains & Seeds',
#  'Pancakes, Waffles, French Toast & Crepes',
#  'Pasta Dinners',
#  'Pasta/Noodles',
#  'Pastry Shells & Fillings',
#  'Pepperoni, Salami & Cold Cuts',
#  'Pickles, Olives, Peppers & Relishes',
#  'Pizza',
#  'Pizza Mixes & Other Dry Dinners',
#  'Plant Based Milk',
#  'Plant Based Water',
#  'Powdered Drinks',
#  'Pre-Packaged Fruit & Vegetables',
#  'Prepared Pasta & Pizza Sauces',
#  'Prepared Soups',
#  'Prepared/Preserved Foods Variety Packs',
#  'Puddings & Custards',
#  'Ready-Made Combination Meals',
#  'Rice',
#  'Salad Dressing & Mayonnaise',
#  'Sauces/Spreads/Dips/Condiments',
#  'Savoury Bakery Products',
#  'Seasoning Mixes, Salts, Marinades & Tenderizers',
#  'Snack, Energy & Granola Bars',
#  'Soda',
#  'Specialty Formula Supplements',
#  'Sport Drinks',
#  'Stuffing',
#  'Sushi',
#  'Sweet Bakery Products',
#  'Syrups & Molasses',
#  'Tea Bags',
#  'Vegetable Based Products / Meals',
#  'Vegetable and Lentil Mixes',
#  'Vegetarian Frozen Meats',
#  'Water',
#  'Weight Control',
#  'Yogurt',
#  'Yogurt/Yogurt Substitutes',
#  'Baking',
#  'Cakes',
#  'Soup',
#  'Oils & Butters',
#  'Dough Based Products',
#  'Flours & Grains',
#  'Meat/Poultry/Other Animals',
#  'Non Alcoholic Beverages',
#  'Cooking Sauces',
#  'Subs, Sandwiches, Wraps & Burittos',
#  'Vegetables']

# %%
def embedd(tokens):
  embedding = np.zeros((10,embedding_size),dtype=float)
  for i,token in enumerate(tokens[:10]):
    if not(token == "" or token == " " or token not in embedding_model.wv):
      embedding[i,:] = embedding_model.wv[token]
  return torch.FloatTensor(embedding)

def embedd_mean(tokens):
  i = 0
  embedding = np.zeros((embedding_size,),dtype=float)
  for token in tokens[:10]:
    if not(token == "" or token == " " or token not in embedding_model.wv):
      embedding += embedding_model.wv[token]
      i += 1
  if i == 0:
    return torch.FloatTensor(embedding)
  return torch.FloatTensor(embedding/i)

def collate_batch(batch):
  code_list, embedding_list = [],[]
  for code, tokens in batch:
    code_list.append(code)
    embedding_list.append(embedd(tokens))
  code_list = torch.LongTensor(code_list)
  embedding_list = torch.stack(embedding_list)
  return code_list, embedding_list

def collate_batch_eval(batch):
  code_list, embedding_list = collate_batch(batch)
  tokens_list = [x for _,x in batch]
  return code_list,embedding_list, tokens_list

# %% [markdown]
# Load the crawled items from file for inloop testing

# %%
class FoodClassificationModel(Module):
  def __init__(self, no_of_classes,device):
    super().__init__()
    p = 0.2
    self.device = device
    self.no_of_classes = no_of_classes
    self.model = torch.nn.Sequential(
        torch.nn.Linear(300, 200),
        torch.nn.LeakyReLU(),
        torch.nn.BatchNorm1d(200),
        torch.nn.Linear(200, 100),
        torch.nn.LeakyReLU(),
        torch.nn.BatchNorm1d(100),
        torch.nn.Linear(100,self.no_of_classes)).to(self.device)
  def forward(self,x):
    return self.model(x)
    
  def get_accuracy(self,X,y):
    y_pred = self.forward(X)
    res = torch.argmax(y_pred, dim=1)
    res = y-res
    l = int(torch.count_nonzero(res))
    count = list(y_pred.shape)[0]
    return (count-l)/count

# %%
class FoodClassificationCnnModel(Module):
  def __init__(self, no_of_classes,device,dropout=0.2):
    super().__init__()
    n_filters = 100
    self.device = device
    self.no_of_classes = no_of_classes
    self.filter1 =  torch.nn.Conv2d(in_channels = 1, 
                                    out_channels = n_filters, 
                                    kernel_size = (3, 300)).to(device)
    self.filter2 =  torch.nn.Conv2d(in_channels = 1, 
                                    out_channels = n_filters, 
                                    kernel_size = (4, 300)).to(device) 
    self.filter3 =  torch.nn.Conv2d(in_channels = 1, 
                                    out_channels = n_filters, 
                                    kernel_size = (5, 300)).to(device)
    self.filter4 =  torch.nn.Conv2d(in_channels = 1, 
                                    out_channels = n_filters, 
                                    kernel_size = (1, 300)).to(device)
    self.linear = torch.nn.Sequential(torch.nn.Linear(4*n_filters,100),
                                      torch.nn.LeakyReLU(),
                                      torch.nn.BatchNorm1d(100),
                                      torch.nn.Linear(100,self.no_of_classes)).to(device)
    self.relu = torch.nn.ReLU().to(device)
    self.dropout = torch.nn.Dropout(dropout).to(device)
  
  def forward(self,x):
    x = x.unsqueeze(1)
    f1 = self.relu(self.filter1(x)).squeeze(3)
    f2 = self.relu(self.filter2(x)).squeeze(3)
    f3 = self.relu(self.filter3(x)).squeeze(3)
    f4 = self.relu(self.filter4(x)).squeeze(3)
    f1 = torch.nn.functional.max_pool1d(f1,f1.shape[2])
    f2 = torch.nn.functional.max_pool1d(f2,f2.shape[2])
    f3 = torch.nn.functional.max_pool1d(f3,f3.shape[2])
    f4 = torch.nn.functional.max_pool1d(f4,f4.shape[2])
    linear = self.dropout(torch.cat((f1,f2,f3,f4),dim=1)).squeeze(2)
    out = self.linear(linear)
    return out
    
  def get_accuracy(self,X,y):
    y_pred = self.forward(X)
    res = torch.argmax(y_pred, dim=1)
    res = y-res
    l = int(torch.count_nonzero(res))
    count = list(y_pred.shape)[0]
    return (count-l)/count

# %%
config = dict(
    lr = 1e-2,
    no_of_classes = fd.no_of_classes,
    batch_size= 50000,
    num_workers=2,
    loss=torch.nn.CrossEntropyLoss(),
    dataset="FoodItem2.1(1,300)Filter",
    epochs=30,
    test_set_size= len(fd_test),
    train_set_size= len(fd),
    early_stop_after=2
)

# %%
config["no_of_classes"]
# Out:
# 108

# %%
model = FoodClassificationCnnModel(config["no_of_classes"],device)

# %%
dataloader = DataLoader(fd,batch_size=config["batch_size"], 
                        collate_fn=collate_batch,pin_memory=True, 
                        shuffle=True,
                        num_workers=config["num_workers"])
dataloader_test = DataLoader(fd_test,batch_size=config["batch_size"], 
                             collate_fn=collate_batch, pin_memory=True,
                             num_workers=config["num_workers"])
optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])
assert len(dataloader.dataset) > len(dataloader_test.dataset)
stopping_func = early_stopping(config["early_stop_after"])
loss_fn = config["loss"]

# %%
assert len(dataloader.dataset) > len(dataloader_test.dataset)

# %%
wandb.login()
run = wandb.init(project="food-classification", entity="gege-hoho", config=config)
# Out:
# wandb: Currently logged in as: gege-hoho (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/gege-hoho/food-classification/runs/3npjpmw9" target="_blank">splendid-jazz-10</a></strong> to <a href="https://wandb.ai/gege-hoho/food-classification" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
config['lr'] = 1e-4

# %%
print(f"Train with LR:{config['lr']}")
assert len(dataloader.dataset) > len(dataloader_test.dataset)
print(device)

for epoch in range(config["epochs"]):
  model.train()
  x1 = time.perf_counter()
  for data in dataloader:    
    y_train = data[0].to(device)
    X_train = data[1].to(device)
    #X_train = X_train.mean(dim=1)
    y_pred = model.forward(X_train)
    loss = loss_fn(y_pred, y_train)
    wandb.log({"train-loss": loss})
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
  #scheduler.step()
  x2 = time.perf_counter()
  print(f"Epoch Time: {x2-x1}")
  wandb.log({"epoch-time": x2-x1})
  if epoch % 1 == 0:
    acc_tr = model.get_accuracy(X_train,y_train)
    print(f"{epoch} Accuracy Train {acc_tr}")
    wandb.log({"train-acc": acc_tr})
    acc_te = 0
    rec_te = np.zeros((len(fd_test.cats),))
    pre_te = np.zeros((len(fd_test.cats),))
    model.eval()
    for i,test in enumerate(dataloader_test):
      y_test = test[0].to(device)
      X_test = test[1].to(device)
      #X_test = X_test.mean(dim=1)
      acc_te += model.get_accuracy(X_test,y_test)
    acc_te = acc_te/(i+1)
    wandb.log({"test-acc": acc_te})
    print(f"{epoch} Accuracy Test {acc_te}")
    if stopping_func(acc_te):
      print("early stopping")
      break
  if epoch % 5 ==0:
    crawled_food = test_crawled(model,fd.cats)[0:500][["meal_name","tokens","category","pct"]]
    wandb.log({"crawled_food": crawled_food})
    print("logged cralwed food")
# Out:
# Train with LR:0.001
# cuda:0
# Epoch Time: 80.27048318800007
# 0 Accuracy Train 0.9260555028462998
# 0 Accuracy Test 0.927246424505286
# Epoch Time: 80.03988636400027
# 1 Accuracy Train 0.9271228652751423
# 1 Accuracy Test 0.9276568500948768
# Epoch Time: 79.92357244600134
# 2 Accuracy Train 0.9285460151802657
# 2 Accuracy Test 0.9287695798319326
# Epoch Time: 80.26891889000035
# 3 Accuracy Train 0.9285163662239089
# 3 Accuracy Test 0.9289629655733262
# Epoch Time: 79.97859717000028
# 4 Accuracy Train 0.9273897058823529
# 4 Accuracy Test 0.9296051179181352
# Epoch Time: 80.37067238300006
# 5 Accuracy Train 0.9302063567362429
# 5 Accuracy Test 0.9302052697207915
# Epoch Time: 80.10600337099822
# 6 Accuracy Train 0.9295837286527514
# 6 Accuracy Test 0.9296266738953646
# Epoch Time: 80.12673555299989
# 7 Accuracy Train 0.9296726755218216
# 7 Accuracy Test 0.9318929357549471
# Epoch Time: 80.3200975189975
# 8 Accuracy Train 0.9293465370018975
# 8 Accuracy Test 0.9315237137435618
# Epoch Time: 80.09411333300159
# 9 Accuracy Train 0.9291093453510436
# 9 Accuracy Test 0.9316751911087016
# early stopping

# %%
torch.save(model,"model93.2")
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 6660... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 6.46MB of 6.46MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch-time</td><td>█▂▄▄▄▂▁▁▄▄▂▁▅▆▂▃▂▂▂▅▃▃▄▄▄▄▁▂▄▂▃▃▄▁▄▂▄▃▃▄</td></tr><tr><td>test-acc</td><td>▁▃▄▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇████████████████████</td></tr><tr><td>train-acc</td><td>▁▃▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr><tr><td>train-loss</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch-time</td><td>80.09411</td></tr><tr><td>model</td><td>FoodClassificationCn...</td></tr><tr><td>test-acc</td><td>0.93168</td></tr><tr><td>train-acc</td><td>0.92911</td></tr><tr><td>train-loss</td><td>0.23755</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 6 media file(s), 5 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">splendid-jazz-10</strong>: <a href="https://wandb.ai/gege-hoho/food-classification/runs/3npjpmw9" target="_blank">https://wandb.ai/gege-hoho/food-classification/runs/3npjpmw9</a><br/>
# Find logs at: <code>./wandb/run-20211129_125058-3npjpmw9/logs</code><br/>

# %%
model = torch.load("model93.2")

# %%
model.eval()
dataloader_eval = DataLoader(fd_test,batch_size=150000, collate_fn=collate_batch_eval, pin_memory=True)
wrong_data =  []
for i,test in enumerate(dataloader_eval):
  y_test = test[0].to(device)
  y_pred = model(test[1].to(device))
  tokens = test[2]
  y_pred = torch.argmax(y_pred, dim=1)
  for y_p, y_t,tokens in zip(y_pred,y_test,tokens):
    if y_p != y_t:
      #print(f"Expected {fd_test.cats[y_t]} Got {fd_test.cats[y_p]} for {tokens}")
      wrong_data.append((fd_test.cats[y_t],fd_test.cats[y_p],tokens)) #actual cat, predicted cat, tokens
    #X_test = X_test.mean(dim=1)
  
  recall,prec = get_evaluation(y_pred,y_test, fd_test.cats)
  cm = get_confusion_matrix(y_pred,y_test,fd_test.cats)
  break

# %%
print("Recall")
print(f"Mean: {np.mean(recall)}")
print(f"Std: {np.std(recall)}")
print(f"Min: {np.min(recall)}")
print(f"Max: {np.max(recall)}")
print("Precision")
print(f"Mean: {np.mean(prec)}")
print(f"Std: {np.std(prec)}")
print(f"Min: {np.min(prec)}")
print(f"Max: {np.max(prec)}")
# Out:
# Recall
# Mean: 0.8978495460956116
# Std: 0.09468527891325575
# Min: 0.4444444444444444
# Max: 0.9819819819819819
# Precision
# Mean: 0.8603575885866698
# Std: 0.13536598460951252
# Min: 0.15384615384615385
# Max: 0.9827132038195587

# %%
print(fd_test.cats[np.argmin(recall)])
print(fd_test.cats[np.argmax(recall)])
print(fd_test.cats[np.argmin(prec)])
print(fd_test.cats[np.argmax(prec)])
# Out:
# Weight Control
# Gelatin, Gels, Pectins & Desserts
# Prepared/Preserved Foods Variety Packs
# Cheese

# %%
for i,(p,r) in enumerate(zip(prec, recall)):
  print(f"{fd_test.cats[i].lower()};{(p*100):.2f}%;{(r*100):.2f}%")
# Out:
# alcohol;85.06%;91.36%
# bacon, sausages & ribs;96.24%;93.57%
# biscuits/cookies;88.69%;94.20%
# bread;95.46%;96.16%
# breakfast drinks;73.33%;68.75%
# breakfast sandwiches, biscuits & meals;54.65%;88.68%
# candy;92.47%;92.82%
# canned & bottled beans;86.35%;90.04%
# canned fruit;95.10%;95.72%
# cereal;97.14%;97.30%
# cereal/muesli bars;83.72%;97.30%
# cheese;98.27%;97.80%
# cheese/cheese substitutes;69.23%;90.00%
# chewing gum & mints;94.83%;93.75%
# chips, pretzels & snacks;96.53%;95.71%
# chocolate;87.03%;85.42%
# vegetable based products / meals;72.41%;89.36%
# vegetable and lentil mixes;77.16%;72.55%
# vegetarian frozen meats;87.29%;89.57%
# water;96.15%;96.63%
# weight control;33.33%;44.44%
# yogurt;98.14%;97.82%
# yogurt/yogurt substitutes;90.83%;98.02%
# baking;90.47%;89.27%
# cakes;95.26%;91.65%
# soup;93.95%;93.15%
# oils & butters;97.77%;96.74%
# dough based products;74.45%;84.39%
# flours & grains;89.92%;94.07%
# meat/poultry/other animals;89.81%;87.17%
# non alcoholic beverages;90.50%;96.43%
# cooking sauces;88.54%;89.98%
# subs, sandwiches, wraps & burittos;89.01%;92.11%
# vegetables;93.95%;94.28%

# %% [markdown]
# TopK accuraccy:

# %%
k = 3
y_pred = model(test[1].to(device))
y_test = test[0].to(device)
topk = torch.topk(y_pred, k, dim=1)
s = 0
count = y_pred.shape[0]
for i in range(topk.indices.shape[1]):
  res = y_test -topk.indices[:,i]
  s += (res == 0).sum()

print(s/count)
# Out:
# tensor(0.9918, device='cuda:0')

# %%
crawled_food = test_crawled(model,fd.cats)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', 100):
  display(crawled_food[0:400][["meal_name","tokens","category","pct"]])
# Out:
#                                              meal_name  \
# 0                         Rockstar - Punched, 8 fl.oz.
# 1    Airbourne - Airbourne Plus beta immune booster...
# 2    Powerade - Zero - Fruit Punch (32 Fl oz), 1 co...
# 3             Homemade - Grilled Chicken Tenders, 4 oz
# 4                              Parmesan cheese, 4 tbsp
# 5                                 Rotini - Pasta, 4 oz
# 6         Kroger - Mini Chocolate Cupcakes, 3 cupcakes
# 7    Powerade - Twisted Blackberry, 1 container (30...
# 8    Homemade - Toasted Ham and Cheese Sandwich, 1 ...
# 9                                     Banana, 1 medium
# 10                          Reign - Lemon Hdz, 8 fl oz
# 11     Starkist - Sriracha Tuna Pouch, 148 g (1 pouch)
# 12               Chuy's - Tortilla Soup (Bowl), 1 bowl
# 13   Blue Diamond - Almond Breeze Almond Milk - Van...
# 14   Bowmar nutrition - Protein Blueberry Cheesecak...
# 15   Airbourne - Airbourne Plus beta immune booster...
# 16   Starbucks - Venti Iced Green Tea Lemonade - Un...
# 17   Starbucks - Turkey Bacon and Egg White Breakfa...
# 18   Powerade - Zero - Fruit Punch (32 Fl oz), 1 co...
# 19   Campbell's Chunky - Chicken Noodle, 1 containe...
# 20   Raising Canes - Box Combo With Toast and Coles...
# 21   Powerade Ion4 - Watermelon Strawberry Wave, 1 ...
# 22   Zico - Watermelon Raspberry Coconut Water, 1 b...
# 23     Signature Cafe - Roasted Shredded Chicken, 3 oz
# 24                                  Blueberries, 1 cup
# 25   Mamma Chia - Chia Squeeze Vitality Snack - Wil...
# 26              Homemade - Grilled Turkey Burger, 6 oz
# 27             Monster - Zero Ultra (Net Carbs), 24 oz
# 28   Starbucks - Venti Iced Green Tea Lemonade - Un...
# 29   Starbucks - Turkey Bacon and Egg White Breakfa...
# 30                              Pancakes - Plain, 1 oz
# 31                                  Blueberries, 1 cup
# 32     Signature Cafe - Roasted Shredded Chicken, 3 oz
# 10                                 [reign, lemon, hdz]
# 11            [starkist, sriracha, tuna, pouch, pouch]
# 12                 [chuys, tortilla, soup, bowl, bowl]
# 13   [blue diamond, almond, breeze, almond, milk, v...
# 14   [bowmar, nutrition, protein, blueberry, cheese...
# 15   [airbourne, airbourne, plus, beta, immune boos...
# 16   [starbucks, venti, iced, green tea, lemonade, ...
# 17   [starbucks, turkey, bacon, egg, white, breakfa...
# 18                        [powerade zero, fruit punch]
# 19                  [campbell chunky, chicken, noodle]
# 20   [raising, cane, box, combo, toast, coleslaw, c...
# 21            [powerade, watermelon, strawberry, wave]
# 22   [zico, watermelon, raspberry, coconut, water, ...
# 23        [signature cafe, roasted, shredded, chicken]
# 24                                         [blueberry]
# 25   [mamma chia, chia squeeze, vitality, snack, wi...
# 26                           [grilled, turkey, burger]
# 27                   [monster, zero, ultra, net carbs]
# 28   [starbucks, venti, iced, green tea, lemonade, ...
# 29   [starbucks, turkey, bacon, egg, white, breakfa...
# 30                                    [pancake, plain]
# 31                                         [blueberry]
# 32        [signature cafe, roasted, shredded, chicken]
# 33           [salted caramel, truffle, blizzard, mini]
# 34   [dairy, queen, hungrbuster, cheese, bacon, bur...
# 35                    [cocoa, cloud, macchiato, venti]
# 36         [starbucks, nitro cold, brew, sweet, cream]
# 37   [starbucks, turkey, bacon, egg, white, breakfa...
# 38                               [avocado, raw, small]
# 39                     [powerade, twisted, blackberry]
# 40    [bell pepper, orange, bell pepper, organic, ozs]
# 41                                   [cucumber, slice]
# 42                                         [blueberry]
# 43                                         [olive oil]
# 44                                      [spinach, raw]
# 45                         [tea, iced, unsweet, fluid]
# 46                     [chicken, express, green, bean]
# 47          [chicken, express, fried, chicken, tender]
# 48            [starbucks, guava, white, tea, lemonade]
# 49                        [kroger, colby jack, cheese]
# 50                               [spinach, raw, bunch]
# 51                                       [egg, medium]
# 52                 [thomas, bagel plain, bagel, bagel]
# 53                                         [blueberry]
# 54            [powerade, watermelon, strawberry, wave]
# 55          [chicken, express, fried, chicken, tender]
# 56    [bell pepper, orange, bell pepper, organic, ozs]
# 57                                      [spinach, raw]
# 58   [starbucks, baja, black bean, veggie, wrap, pa...
# 59   [blue diamond, almond, breeze, almond, milk, v...
# 60   [bowmar, nutrition, protein, blueberry, cheese...
# 61               [starbucks, nitro cold, brew, grande]
# 62   [starbucks, turkey, bacon, egg, white, breakfa...
# 63                   [chicken, spinach, veggie, salad]
# 64               [starbucks, nitro cold, brew, grande]
# 65   [country, time, pink lemonade, drink mix, packet]
# 66                   [bowmar, nutrition, green, scoop]
# 67              [shipleys, donut, cinnamon roll, roll]
# 68             [chocolate, cupcake, frosting, cupcake]
# 69                    [powerade, strawberry, lemonade]
# 70           [chip ahoy, white, fudge, chunky, cookie]
# 71                          [turkey, cheese, sandwich]
# 72           [chip ahoy, white, fudge, chunky, cookie]
# 73                               [french, fry, potato]
# 74                                      [cheeseburger]
# 75   [blue diamond, almond, breeze, almond, milk, v...
# 76                      [frosted flake, frosted flake]
# 77   [country, time, pink lemonade, drink mix, packet]
# 78                   [bowmar, nutrition, green, scoop]
# 79   [blue diamond, almond, breeze, almond, milk, v...
# 80                     [cheerio, honey, nut, cherrios]
# 81             [soft, chocolate, chip, cookie, cookie]
# 82                          [turkey, cheese, sandwich]
# 83                      [powerade zero, white, cherry]
# 84              [heb, portabella, onion, pasta, sauce]
# 85                                [barilla, spaghetti]
# 86              [touchpoint, roasted, brussels sprout]
# 87             [pompeian balsamic, vinegar, aged, oak]
# 88              [jif, chocolate, cheesecake, hazelnut]
# 89                 [thomas, bagel plain, bagel, bagel]
# 90                                 [bang, frosé, rosé]
# 91                       [welchs concord, grape jelly]
# 92            [chicken, mayonaise, sandwich, sandwich]
# 93                       [buttermilk biscuit, biscuit]
# 94                                [barilla, spaghetti]
# 95              [heb, portabella, onion, pasta, sauce]
# 96                    [domino, stuffed, cheesy, bread]
# 97                [domino, chicken, alfredo, tin, tin]
# 98                               [green, olive, olive]
# 99   [tom, thumb, philadelphia, style, philly, sand...
# 100                          [border, guacamole, side]
# 101                      [border, chip, salsa, basket]
# 102              [starbucks, nitro cold, brew, grande]
# 103  [blue diamond, almond, breeze, almond, milk, v...
# 104                               [ovaltine, ovaltine]
# 105    [sunrise, energy bar, sunrise, energy bar, bar]
# 106                            [mindy, lu, apple, pie]
# 107                             [red bull, sugar free]
# 108  [safeway, turkey, deli, sandwich, deli, sandwich]
# 109                               [pepperoni, alfredo]
# 110                        [red bull, purple, edition]
# 111              [starbucks, nitro cold, brew, grande]
# 112  [bowmar, nutrition, protein, blueberry, cheese...
# 113  [blue diamond, almond, breeze, almond, milk, v...
# 114                           [donut hole, donut hole]
# 115                               [pepperoni, alfredo]
# 116                               [bang, peach, mango]
# 117    [sunrise, energy bar, sunrise, energy bar, bar]
# 118                         [beefaroni, chef boyardee]
# 119                          [smores, smores, cracker]
# 120                     [eurest, pulled, kahlua, pork]
# 121                                       [fried rice]
# 122                 [frozen, bean, mocha latte, fluid]
# 123  [cheesecake factory, kahlua, cocoa, coffee, ch...
# 124              [uncle, julios, frozen, swirl, swirl]
# 125  [uncle, julios, grilled, fish, taco, full, pla...
# 126       [starbucks, blueberry, black, tea, lemonade]
# 127  [starbucks, turkey, bacon, egg, white, breakfa...
# 128   [generic, frosted, strawberry, cupcake, cupcake]
# 129             [signature cafe, mediterranean, salad]
# 130                   [runa clean, energy drink, lime]
# 131         [dietz watson, turkey, sandwich, sandwich]
# 132  [subway, garlic, steak, provolone, ciabatta, s...
# 133               [starbucks, cocoa, cloud, macchiato]
# 134              [starbucks, spinach feta, wrap, wrap]
# 135                           [mr butterworths, syrup]
# 136                      [fluffy, french toast, slice]
# 137                      [great value, tator, tot tot]
# 138                          [hamburger bun, bun, bun]
# 139                [manwich, sloppy joes, sloppy joes]
# 140  [nothing, bundt cake, bundtini, lemon, frostin...
# 141   [border, street, style, mini, taco, steak, taco]
# 142                 [frozen, bean, mocha latte, fluid]
# 143  [nothing, bundt cake, bundtini, lemon, frostin...
# 144      [grilled chicken, cheese, sandwich, sandwich]
# 145                                 [baked, curly fry]
# 146          [original, tommys, chili, burger, burger]
# 147  [pepperidge farm, milano, milk, chocolate, coo...
# 148  [country, time, pink lemonade, drink mix, packet]
# 149                  [monster, zero, ultra, net carbs]
# 150    [sunrise, energy bar, sunrise, energy bar, bar]
# 151                         [turkey, cheese, sandwich]
# 152                         [beefaroni, chef boyardee]
# 153            [albertsons, red velvet, cooky, cookie]
# 154                      [walmart, chocolate, cupcake]
# 155    [sunrise, energy bar, sunrise, energy bar, bar]
# 156                         [turkey, cheese, sandwich]
# 157                                 [baked, curly fry]
# 158            [cheeseburger, bacon, jalapeno, burger]
# 159                 [progresso, chicken, corn chowder]
# 160                          [turkey, grilled, cheese]
# 161                              [brown sugar, packed]
# 162                [sweet, potato, medium, inch, long]
# 163              [monster, zero calorie, energy drink]
# 164     [bolthouse farm, strong, proteinvanilla, chai]
# 165                       [brown sugar, sweet, potato]
# 166  [sargento, snack, partskim mozzarella, string ...
# 167                            [yoplait, oui, coconut]
# 168                        [dole, peach, cream, fruit]
# 169                      [powerade, sugar free, grape]
# 170                 [king hawaiian, sweet, roll, roll]
# 171                 [frozen, bean, mocha latte, fluid]
# 172                                  [tatertot, nacho]
# 173      [quiktripqt, steak, cheese, taquito, taquito]
# 174             [cheesy, pepperjack, taquito, taquito]
# 175                     [powerade zero, white, cherry]
# 176  [blue diamond, almond, breeze, almond, milk, v...
# 177                               [ovaltine, ovaltine]
# 178                       [brown sugar, sweet, potato]
# 179  [sargento, snack, partskim mozzarella, string ...
# 180                        [dole, peach, cream, fruit]
# 181                                 [dole, grapefruit]
# 182                 [king hawaiian, sweet, roll, roll]
# 183                       [powerade zero, one, bottle]
# 184            [bang bang, peach, mango, energy drink]
# 185                                  [tatertot, nacho]
# 186                 [king hawaiian, sweet, roll, roll]
# 187  [bowmar, nutrition, protein, blueberry, cheese...
# 188                                     [turkey, wrap]
# 189              [starbucks, nitro cold, brew, grande]
# 190  [bowmar, nutrition, protein, blueberry, cheese...
# 191                     [powerade zero, white, cherry]
# 192                                 [dole, grapefruit]
# 193                        [dole, peach, cream, fruit]
# 194  [sargento, snack, partskim mozzarella, string ...
# 195                       [brown sugar, sweet, potato]
# 196         [starkist, honey, bbq, tuna, pouch, pouch]
# 197               [cheeseburger, cheeseburger, burger]
# 198                                 [baked, curly fry]
# 199       [hershey, kit kat, king size, three, finger]
# 200  [monster energy, zero sugar, zero, carb, ultra...
# 201          [delicious, vanilla, coconutmilk, yogurt]
# 202           [starbucks, guava, white, tea, lemonade]
# 203  [starbucks, turkey, bacon, egg, white, breakfa...
# 204                          [protein, infused, water]
# 205                        [litehouse, ranch dressing]
# 206  [taylor farm, vegetable, snack tray, carrot, b...
# 207                        [whole, food, mango, berry]
# 208                  [alcoholic, beverage, rice, sake]
# 209       [wegmans, spicy, tuna, roll, package, piece]
# 210                                 [dole, grapefruit]
# 211                        [dole, peach, cream, fruit]
# 212                          [grilled chicken, tender]
# 213           [herbert, lemonade, raspberry, lemonade]
# 214       [subway, garlic, steak, provalone, sandwich]
# 215                                [cheese, provolone]
# 216                [ground beef, burger patty, burger]
# 217                                      [carne asada]
# 218                [icee, blue raspberry, freeze tube]
# 219                 [golden, graham, smores, bar, bar]
# 220                 [frozen, bean, mocha latte, fluid]
# 221        [everything bagel, crusted cod, cod, filet]
# 222           [bluebell, southern, blackberry cobbler]
# 223                      [cheezits, cheezits, cracker]
# 224                   [snack pack, pudding, chocolate]
# 225                                            [salsa]
# 226       [tostidos, original, restaurant style, chip]
# 227                                   [banana, medium]
# 228  [blue diamond, almond, breeze, almond, milk, v...
# 229  [bowmar, nutrition, protein, blueberry, cheese...
# 230            [soft, chocolate, chip, cookie, cookie]
# 231           [cinnamon, pop, tart, pop, tart, pastry]
# 232                                 [dole, grapefruit]
# 233                [cheddar, cheese, sharp, tillamook]
# 234                         [oreida, tater tot, piece]
# 235             [kroger, cake, chocolate, cake, slice]
# 236                            [chicken, kabob, kabob]
# 237     [starbucks, coffee, mocha, frappuccino, fluid]
# 238           [cinnamon, pop, tart, pop, tart, pastry]
# 239                                   [banana, medium]
# 240  [blue diamond, almond, breeze, almond, milk, v...
# 241  [bowmar, nutrition, protein, blueberry, cheese...
# 242  [sargento, snack, partskim mozzarella, string ...
# 243                               [cheezit, snap, bag]
# 244                                 [dole, grapefruit]
# 245                     [hershey, cooky, cream, block]
# 246                 [campbell chunky, chicken, noodle]
# 247                      [welchs concord, grape jelly]
# 248              [toast, butter, toast, butter, slice]
# 249       [subway, garlic, steak, provalone, sandwich]
# 250                  [carb, master, blueberry, muffin]
# 251                   [powerade, strawberry, lemonade]
# 252   [generic, frosted, strawberry, cupcake, cupcake]
# 253                     [snack pack, vanilla, pudding]
# 254                        [dole, peach, cream, fruit]
# 255  [sandwich, burger, roast beef, sandwich, chees...
# 256                                   [banana, medium]
# 257                                     [cheeseburger]
# 258       [starbucks, caramel macchiato, almond, milk]
# 259  [starbucks, turkey, bacon, egg, white, breakfa...
# 260                                   [banana, medium]
# 261                 [powerade zero, mixed berry, blue]
# 262                  [carb, master, blueberry, muffin]
# 263                        [dole, peach, cream, fruit]
# 264                     [snack pack, vanilla, pudding]
# 265  [safeway, deli, turkey, salad, hoagie, sandwic...
# 266                        [slim fast, mct oil, tbsps]
# 267                        [powerade zero, strawberry]
# 268               [two, good, blueberry, greek yogurt]
# 269       [teavana, meyer lemon, black, tea, iced tea]
# 270       [primo taglio, mozzarella, prosciutto, roll]
# 271                              [avocado, raw, small]
# 272  [blt salad, chicken, bacon, signature cafe, sa...
# 273                                      [costco, cod]
# 274  [golden flake, louisiana hot, sauce, chicharro...
# 275      [generic, haas, avocado, large, raw, avocado]
# 276    [heart, ghee, butter, madagascar vanilla, bean]
# 277                        [slim fast, mct oil, tbsps]
# 278                            [coffee, black, coffee]
# 279    [boathouse, cilantro avocado, yogurt, dressing]
# 280  [johnsonville, sausage, beddar cheddar, smoked...
# 281                        [slim fast, mct oil, tbsps]
# 282  [golden flake, louisiana hot, sauce, chicharro...
# 283          [generic, carbmaster, banana, cream, pie]
# 284                                   [almond, almond]
# 285                    [kroger, mexican style, cheese]
# 286                                     [spinach, raw]
# 287      [generic, chicken breast, grilled, net carbs]
# 288                                       [egg, large]
# 289                                     [keto, coffee]
# 290  [sargento, snack, partskim mozzarella, string ...
# 291                        [slim fast, mct oil, tbsps]
# 292            [heb, natural, extra virgin, olive oil]
# 293       [kroger, carb, master, yogurtcinnamon, roll]
# 294                                       [red, onion]
# 295      [generic, haas, avocado, large, raw, avocado]
# 296   [simple truth, organic, baby spinach, corrected]
# 297   [kroger, shredded, mexican style, blend, cheese]
# 298  [golden flake, louisiana hot, sauce, chicharro...
# 299                                       [egg, large]
# 300                                     [keto, coffee]
# 301  [country, time, pink lemonade, drink mix, packet]
# 302    [kroger, lower sodium, turkey breast, peppered]
# 303  [starkist tuna, bold, tuna creation, tapatio, ...
# 304    [boathouse, cilantro avocado, yogurt, dressing]
# 305  [kroger carbmaster, cultured dairy, blend, str...
# 306  [sargento, snack, partskim mozzarella, string ...
# 307      [generic, haas, avocado, large, raw, avocado]
# 308   [kroger, shredded, mexican style, blend, cheese]
# 309   [simple truth, organic, baby spinach, corrected]
# 310  [sargento, snack, partskim mozzarella, string ...
# 311                                       [egg, large]
# 312                    [bowmar, nutrition, pre, scoop]
# 313               [pumpkin pie, fat bomb, green, keto]
# 314                                     [keto, coffee]
# 315  [country, time, pink lemonade, drink mix, packet]
# 316  [sargento, snack, partskim mozzarella, string ...
# 317  [kroger carbmaster, strawberry, pomegranate, y...
# 318      [generic, haas, avocado, large, raw, avocado]
# 319  [boar head, brand, naturally, smoked, sliced, ...
# 320                [minced garlic, garlic, wpotassium]
# 321  [pure, blend, avocado oil, butter, pure, blend...
# 322    [philadelphia, cream, cheese, spread, original]
# 323   [simple truth, organic, baby spinach, corrected]
# 324                              [mac, bbq, pork rind]
# 325       [kroger, carb, master, yogurtcinnamon, roll]
# 326             [kroger, boneless, beef, chunk, steak]
# 327                  [green, giant, riced cauliflower]
# 328              [muscle milk, chocolate, muscle milk]
# 329                     [cheerio, oat, crunch, almond]
# 330                       [market pantry, whole, milk]
# 331            [peterson, farm, triple, cherry, blend]
# 332        [friendly farm, greek nonfat, yogurt plain]
# 333        [quest, vanilla, milkshake, protein powder]
# 334  [clancys, natural, tortilla chip, restaurant s...
# 335             [kraft, miracle whip, light, dressing]
# 336  [target, market pantry, chunk light, tuna wate...
# 337  [pepperidge farm, farmhouse, hearty, white, sl...
# 338                          [fair, food, funnel cake]
# 339         [kind, breakfast, bar, peanut butter, bar]
# 340                                [cruzan, aged, rum]
# 341                                [cruzan, aged, rum]
# 342        [quest, vanilla, milkshake, protein powder]
# 343        [friendly farm, greek nonfat, yogurt plain]
# 344            [peterson, farm, triple, cherry, blend]
# 345  [clancys, natural, tortilla chip, restaurant s...
# 346             [heinens, wild, salmon, veggie burger]
# 347                        [red, seedless grape, usda]
# 348  [clancys, natural, tortilla chip, restaurant s...
# 349             [heinens, salmon burger, spinach feta]
# 350             [favorite day, moose track, ice cream]
# 351  [new, belgium, brewing company, trippel, ale, ...
# 352              [safeway, carrot, cake, carrot, cake]
# 353                        [kfc, mashed potato, gravy]
# 354   [hoagie, bun, italian, bread, hoagie, bun, roll]
# 355                     [johnsonville bratwurst, link]
# 356  [chicken breast, usda, chicken breast, meat, c...
# 357               [usda, squash, summer, variety, raw]
# 358  [lofthouse, cooky, crackle cooky, chocolate, b...
# 359                                   [absolut, vodka]
# 360                           [high, noon, watermelon]
# 361              [safeway, carrot, cake, carrot, cake]
# 362                     [cheerio, oat, crunch, almond]
# 363                       [market pantry, whole, milk]
# 364           [market pantry, extra virgin, olive oil]
# 365                              [pita, aladdin, pita]
# 366  [chicken breast, usda, chicken breast, meat, c...
# 367              [dutch maid, updated, radish, radish]
# 368               [usda, chicken, dark, meat, roasted]
# 369  [lofthouse, cooky, crackle cooky, chocolate, b...
# 370             [favorite day, moose track, ice cream]
# 371                                [cruzan, aged, rum]
# 372              [mar, ice cream, bar, ice cream, bar]
# 373                       [market pantry, whole, milk]
# 374                     [cheerio, oat, crunch, almond]
# 375  [clancys, natural, tortilla chip, restaurant s...
# 376  [ocean spray, light, cranberry, raspberry, juice]
# 377           [market pantry, frozen, mixed vegetable]
# 378  [chicken breast, usda, chicken breast, meat, c...
# 379              [dutch maid, updated, radish, radish]
# 380           [market pantry, extra virgin, olive oil]
# 381  [chicken breast, usda, chicken breast, meat, c...
# 382  [kind, breakfast, protein bar, dark, chocolate...
# 383                         [abound, omega trail, mix]
# 384  [kind, breakfast, blueberry, almondcorrected, ...
# 385                                   [absolut, vodka]
# 386        [friendly farm, greek nonfat, yogurt plain]
# 387                        [vip, cherry, berry, blend]
# 388         [kirkland, frozen, cherry, frozen, cherry]
# 389  [quest, chocolate, milkshake, protein, powderlmc]
# 390  [clancys, natural, tortilla chip, restaurant s...
# 391                        [red, seedless grape, usda]
# 392             [pepperidge farm, grain, bread, slice]
# 393  [heinens, roast beef, wrap, bleu, cheese, carm...
# 394  [aldi, happy farm, deli sliced, colby jack, sl...
# 395             [kraft, miracle whip, light, dressing]
# 396  [target, market pantry, chunk light, tuna wate...
# 397  [heinens, vegetarian, tomato basil, bisque, soup]
# 398                         [abound, omega trail, mix]
# 399  [kemps, corrected, ice cream, sandwich, vanill...
#
#                                             category       pct
# 0                                               Soda  0.303856
# 1    Fruit & Vegetable Juice, Nectars & Fruit Drinks  0.800493
# 2                                       Other Drinks  0.305022
# 3                           Frozen Dinners & Entrees  0.604318
# 4                                             Cheese  0.978229
# 5                                      Pasta/Noodles  0.913943
# 6                                              Cakes  0.999972
# 7                                              Candy  0.818400
# 8                 Subs, Sandwiches, Wraps & Burittos  0.950372
# 9                                             Cheese  0.156353
# 10                                             Cakes  0.416545
# 11                                    Fish & Seafood  0.695198
# 12                                              Soup  0.811014
# 13                                  Plant Based Milk  0.999867
# 14                      Snack, Energy & Granola Bars  0.505080
# 358                               Cookies & Biscuits  0.967740
# 359                    Prepared Pasta & Pizza Sauces  0.978270
# 360                                             Soda  0.921935
# 361                                            Cakes  0.978758
# 362                                           Cereal  1.000000
# 363                                             Milk  0.998360
# 364                                   Oils & Butters  0.999872
# 365                                            Bread  0.899712
# 366                                Cooked & Prepared  0.934035
# 367              Pickles, Olives, Peppers & Relishes  0.735412
# 368                       Meat/Poultry/Other Animals  0.883048
# 369                               Cookies & Biscuits  0.967740
# 370                        Ice Cream & Frozen Yogurt  0.984723
# 371                                           Cheese  0.589716
# 372                        Ice Cream & Frozen Yogurt  0.999029
# 373                                             Milk  0.998360
# 374                                           Cereal  1.000000
# 375                         Chips, Pretzels & Snacks  1.000000
# 376  Fruit & Vegetable Juice, Nectars & Fruit Drinks  0.956635
# 377                                       Vegetables  0.999780
# 378                                Cooked & Prepared  0.934035
# 379              Pickles, Olives, Peppers & Relishes  0.735412
# 380                                   Oils & Butters  0.999872
# 381                                Cooked & Prepared  0.934035
# 382                     Snack, Energy & Granola Bars  0.999845
# 383                         Chips, Pretzels & Snacks  0.999098
# 384                     Snack, Energy & Granola Bars  0.999386
# 385                    Prepared Pasta & Pizza Sauces  0.978270
# 386                                           Yogurt  0.999999
# 387          Frozen Fruit & Fruit Juice Concentrates  0.992722
# 388          Frozen Fruit & Fruit Juice Concentrates  0.982703
# 389         Energy, Protein & Muscle Recovery Drinks  0.540361
# 390                         Chips, Pretzels & Snacks  1.000000
# 391                  Pre-Packaged Fruit & Vegetables  0.998757
# 392                                            Bread  0.999899
# 393               Subs, Sandwiches, Wraps & Burittos  0.999988
# 394                                           Cheese  0.999840
# 395                      Salad Dressing & Mayonnaise  0.999960
# 396                                   Fish & Seafood  0.999380
# 397                                             Soup  0.998681
# 398                         Chips, Pretzels & Snacks  0.999098
# 399                        Ice Cream & Frozen Yogurt  0.999711

# %%
bigram_model[fd.preprocess("red bull".split(" "))]
# Out:
# ['red bull']

# %%
x = embedd(bigram_model[fd.preprocess("FRUIT WAVE".split(" "))]).float().to(device)
x = x.unsqueeze(0)
print(x.shape)
model.eval()
z = model.forward(x)
ss = torch.nn.Softmax()
z2 = ss(z)
fd.cats[torch.argmax(z2, dim=1)]
# z = m2(x)
# z2 = ss(z)
#topk = torch.topk(z2,3, dim=1).values.cpu()#torch.argmax(z2, dim=1)
#print(topk)
#for x in topk:
#  print(fd.cats[x])
# Out:
# torch.Size([1, 10, 300])
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   import sys
# 'Soda'

# %%
#Model as in Convolutional Neural Networks for Sentence Classification
class FoodClassificationCnnModelUsualElevator7(Module):
  def __init__(self, no_of_classes,device):
    super().__init__()
    n_filters = 100
    self.device = device
    self.no_of_classes = no_of_classes
    self.filter1 =  torch.nn.Conv2d(in_channels = 1, 
                                    out_channels = n_filters, 
                                    kernel_size = (3, 300)).to(device)
    self.filter2 =  torch.nn.Conv2d(in_channels = 1, 
                                    out_channels = n_filters, 
                                    kernel_size = (4, 300)).to(device) 
    self.filter3 =  torch.nn.Conv2d(in_channels = 1, 
                                    out_channels = n_filters, 
                                    kernel_size = (5, 300)).to(device)
    self.linear = torch.nn.Sequential(torch.nn.Linear(3*n_filters,100),
                                      torch.nn.LeakyReLU(),
                                      torch.nn.BatchNorm1d(100),
                                      torch.nn.Linear(100,self.no_of_classes)).to(device)
    self.relu = torch.nn.ReLU().to(device)
    self.dropout = torch.nn.Dropout(0.2).to(device)
  
  def forward(self,x):
    x = x.unsqueeze(1)
    f1 = self.relu(self.filter1(x)).squeeze(3)
    f2 = self.relu(self.filter2(x)).squeeze(3)
    f3 = self.relu(self.filter3(x)).squeeze(3)
    f1 = torch.nn.functional.max_pool1d(f1,f1.shape[2])
    f2 = torch.nn.functional.max_pool1d(f2,f2.shape[2])
    f3 = torch.nn.functional.max_pool1d(f3,f3.shape[2])

    linear = self.dropout(torch.cat((f1,f2,f3),dim=1)).squeeze(2)
    out = self.linear(linear)
    return out
    
  def get_accuracy(self,X,y):
    y_pred = self.forward(X)
    res = torch.argmax(y_pred, dim=1)
    res = y-res
    l = int(torch.count_nonzero(res))
    count = list(y_pred.shape)[0]
    return (count-l)/count

# %%
"""
wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None,
                        y_true=np.array(y_test.cpu()), preds=np.array(y_pred.cpu()),
                        class_names=fd_test.cats)})
                        """

# %%
#version for mean embedding
"""
m2 = model.eval()

m2.eval()
crawled_food = pd.read_csv("data/crawled.csv")
crawled_food["tokens"] = crawled_food.apply(lambda row: bigram_model[fd.preprocess(row["meal_name"])], axis=1)

print("tokenized now lets go to embedding")
#todo check if any tokens have 0 embedding
crawled_food["embedding"] = crawled_food.apply(lambda row: embedd_mean(row["tokens"]),axis=1)


print("embedded")
#filter things with 0 embedding
null_embedding = crawled_food["embedding"].isnull()
food_null_embedding = crawled_food[null_embedding]
crawled_food= crawled_food[~null_embedding]
print(len(crawled_food))
x = crawled_food.embedding.apply(pd.Series)
x = torch.from_numpy(x.values).float().to(device)
y = m2(x)
y = torch.argmax(y, dim=1)
y = y.cpu().numpy()
crawled_food["category"] = np.nan
y
j = 0
for i,z in enumerate(~null_embedding):

  if z:
    crawled_food["category"][i] = fd.cats[y[j]]
    j+= 1
"""
# Out:
# tokenized now lets go to embedding
# embedded
# 21039
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-83-c0be6f25ee11> in <module>()
#      19 x = crawled_food.embedding.apply(pd.Series)
#      20 x = torch.from_numpy(x.values).float().to(device)
# ---> 21 y = m2(x)
#      22 y = torch.argmax(y, dim=1)
#      23 y = y.cpu().numpy()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-10-c1e100879836> in forward(self, x)
#      24   def forward(self,x):
#      25     x = x.unsqueeze(1)
# ---> 26     f1 = self.relu(self.filter1(x)).squeeze(3)
#      27     f2 = self.relu(self.filter2(x)).squeeze(3)
#      28     f3 = self.relu(self.filter3(x)).squeeze(3)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
#     447
#     448 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     441                             _pair(0), self.dilation, self.groups)
#     442         return F.conv2d(input, weight, bias, self.stride,
# --> 443                         self.padding, self.dilation, self.groups)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: Expected 4-dimensional input for 4-dimensional weight [100, 1, 3, 300], but got 3-dimensional input of size [21039, 1, 300] instead
